# %%
ID = "101615093"

# %% [markdown]
# # Assignment 1 - Prerequisites Assessment
#
# We will use **python** as the programming language for all the coding assignments in this course.
# You can also recap your skills here [python turorial](https://docs.python.org/3/tutorial/).
# > Please note that if you do not have any previous Python experience, then the course may require more than 5 ECTs of workload.
#
# ### Learning outcomes
# Upon completing this assignment, you will be able to:
#
# 1. Understand the characteristics of digital health data and their applications.
#
# 2. Apply common analysis tasks for digital health data.
#
# 3. Become acquainted with the basic usage of all the techniques you will need in future assignments and project work.
#
# For those of you already familiar with python coding in data science and machine learning field, this assessment will also give you a quick recap. Any detailed concepts and non-trivial techniques will be introduced under each assignment respectively.
#
# For completing the assignments, you will need some general knowledge of data science, data visualization and a tiny bit from machine learning.
#
# Don't panic even if you have **absolute zero** or **very limited** experience with topics mensioned above, since the course primarily aims at **undergraduate students** and it would not be to difficult for you to solve the tasks.
#
#
# ## Table of Contents
#
# * [Chapter 1: Concept of digital health data](#chapter_1)
# * [Chapter 2: Data analysis workflow ](#chapter_2)
# * [Chapter 3: Practice: Data analysis workflow ](#chapter_3)
#     * [Chapter 3.1: Importing basic packages](#chapter_3_1)
#     * [Chapter 3.2: Concept of data types](#chapter_3_2)
#     * [Chapter 3.3: Data handling and preprocesing](#chapter_3_3)
#     * [Chapter 3.4: Plotting techniques (visualization)](#chapter_3_4)
#     * [Chapter 3.5: Analysis and statistical tests](#chapter_3_4)
# * [Chapter 4: Basic concepts of Machine Learning](#chapter_4)
#     * [Chapter 4.1: Supervised learning](#chapter_4_1)
#     * [Chapter 4.2: Unsupervised learning](#chapter_4_2)
#     * [Chapter 4.3: Natural languages processing (NLP)](#chapter_4_3)
#
# * [References](#references)

# %% [markdown]
# # Chapter 1. Concept of digital health data <a class="anchor" id="chapter_1"></a>
#
# Owing to the rapid adoption of eletronic health system and the ubiquitious of mobile and wearable devices, researchers have been blessed with access to an immensely rich and non-intrusive personal data source, which is termed as *digital health data*. According to the World Health Organization (WHO), digital health is an umbrella term that covers multiple aspects, such as mobile health (mHealth), digital health records, personalized medicine etc [1]. Through the collection and manipulation of personal data from different sources, researchers can extract meaningful behaviour digital features such as the number of step counts per day, sleep duration each night, or the number of outgoing/incoming calls.
#
# So, what can we do with those features? Nowadays, health and behavioural digital features are commonly used in predictive modeling or association discovery. For instance, by monitoring measures related to sleep (total sleep time, time on bed), researchers have found [significant positive associations between total sleep time and depression](https://www.frontiersin.org/articles/10.3389/fpsyt.2021.625247/full) [2]. In a same manner, duration of incoming and outgoing calls/day and the number and duration of incoming calls/day have beed utilized to [predict bipolar disorder episodes](https://doi.org/10.1111/bdi.12332) [3], thus provide opportunity for relapse intervention. Moreover, natural language processing techniques have been used to [infer evidences of suicide risk from social media posts](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5659860/) [4]. Digital health applications have been continuously gaining traction in the healthcare landscape and playing an increasingly important role in the policy-making process.
#
# In this course, we will mainly deal with behavioural data. Due to its multi-sensor and longitudinal nature, behavioural data possesses the following characteristics:
#
# 1. **Noise and missingness**. Noise and missingness occur for various reasons: participants drop out of surveys, data entry errors, or even the sudden death of individuals. Dealing with noise and missingness is one of the most important parts in all projects involving digital health data.
#
# 2. **Unstructured and fragmentend**. As mentioned above, digital health data can be gathered from various sources and thus are highly fragmented. The data often come in unstandardized format (physician notes, blog posts), which makes it difficult to process and digest. Curating and maintaining steady data streams is a challenge in itself.
#
# 3. **Privacy and security**. Digital health data is extremely personal and sensistive, and thus must be handled with utmost care. Problems surrounding privacy policies and proper handling of digital health data will be discussed later in the course.
#
# Inevitably, we can see that proper cleaning and preprocessing of the data already make up a big proportion of the allocated time for a digital health project. In this assignment, we will go through all the steps for a common digital health data analysis workflow, with extra focus on the preprocessing phase. We will also have a chance to practice on a real life longitudinal dataset.

# %% [markdown]
# # Chapter 2: Data analysis workflow <a class="anchor" id="chapter_2"></a>
# A common data analysis workflow often consists of five stages. We will provide a description for each stage and some corresponding packages that you might want to use.
#
# **1. Loading**
#
# In this stage, we simply read/load data from different sources: APIs, csv files, databases etc. One of the most popular frameworks for reading and manipulating data is [pandas](https://pandas.pydata.org/). Although there are many ways to gather the data, we will only use pandas to read from csv files in this course.
#
# **2. Preprocessing**
#
# Properly the most time-consuming step in the workflow. There are several things we could do here. We can start with investigating the data types, checking various statistics (min, max, mean, standard deviation values). Then, we can follow with examining data quality (visualizing missingness, detecting outliers), dropping duplicates, or scaling and standardizing values. The amount of steps can vary greatly based on the data. Once again, [pandas](https://pandas.pydata.org/) provides many useful functions for those tasks. On top of that, we often use [numpy](https://numpy.org/) for data manipulation. For specific computational problems, such as calculating distances or sampling from different distributions, we can use [scikit-learn](https://scikit-learn.org/stable/) or [scipy](https://www.scipy.org/).
#
# **3. Explanatory data analysis (EDA)**
#
# An image speaks a thousand words. Data visualization helps us gain insights from our data, discover underlying structures, and reveal relationship between variables. The most common visualization library is [matplotlib.pyplot](https://matplotlib.org/). For more beautiful and advanced plots, refers to [seaborn](https://seaborn.pydata.org/). Finally, if you need interactive plots, use [plotly](https://plotly.com/).
#
# **4. Modeling**
#
# Modeling refers to applying some algorithms on our dataset to achieve a desired output. The output varies based on our needs. We might want to predict some metrics, or to find some associations between the variables. We might also one to discover clusters within our data, or to interpret the structure of some texts. Regardless of the tasks, you can utilize [scikit-learn](https://scikit-learn.org/stable/) to build the model that suits your need. If you want to use traditional statistical models, refers to [statsmodel](https://www.statsmodels.org/stable/index.html). For Natural languuage processing framework, we will discuss in the end of this assignment. More advanced methods like Deep Learning will not be covered in this course.
#
# **5. Evaluation**
#
# The final step is to interpret and visualize the results we just extracted from our model. This steps might include choosing the best model (through cross-validation, AICs comparison), or examining the quality of our model (checking goodness-of-fit, reliablity of estimates). After we are satisfied with the results, we can process to make some nice plots to demonstrate our results and put them somewhere, on a poster or a paper for example. We will, however, not go too deep into the details of this step in this assignment.
#
# Finally, for a nice overview of the workflow, refers to this [link](https://aaltoscicomp.github.io/data-analysis-workflows-course/chapter-1-understanding/).
#
# ### Extra reading for reference
#
# - [15-python-libraries-for-data-science/](https://www.dataquest.io/blog/15-python-libraries-for-data-science/)
# - [top-20-python-libraries-for-data-science](https://bigdata-madesimple.com/top-20-python-libraries-for-data-science/)
# - [numpy tutorial](https://cs231n.github.io/python-numpy-tutorial/#numpy)
# - [pandas userguide](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)
# - [an introduction to machine learning with scikit-learn](https://scikit-learn.org/stable/tutorial/basic/tutorial.html)

# %% [markdown]
# # Chapter 3: Practice: Data analysis workflow <a class="anchor" id="chapter_3"></a>
# Enough with the theory! In this chapter, we will apply what we have just learnt into practice. We will perform a basic analysis workflow on a real dataset ([Pima Indian diabetes](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database)).

# %% [markdown]
# ## Chapter 3.1: Importing basic packages <a class="anchor" id="chapter_3_1"></a>
#
# Run the next cell to import baseline packages.

# %%
import numpy as np # scientific computing
import pandas as pd # data loading and processing
import os # os operations
import matplotlib.pyplot as plt # for generating figures
import seaborn as sns # for generating visualizations, better support with pandas than matplotlib
import json # json package
from datetime import datetime # datetime can handle objects with certian date format
from tqdm.notebook import tqdm # progress bar

if 'AALTO_JUPYTERHUB' in os.environ:
    # using jupyter sharedata directory
    DATA = '/coursedata/pa1/'
else:
    DATA = '../../data/pa1/'

np.random.seed(123) # set random seed
plt.rcParams['font.size'] = 20

# %% [markdown]
# ## Chapter 3.2: Concepts of Data types <a class="anchor" id="chapter_3_2"></a>

# %% [markdown]
# <!-- https://www.linkedin.com/posts/spotlit-ai_introducing-data-science-activity-6811549253794619394-m1eS/ -->
# In order to understand the data, it is essential to know the data types you are dealing with. It helps to select the right tools for visualization and further analysis.
#
# Numerical data:
# - Discrete data - the data that consists of numerical values that are distinct and separate. In other words, this type of data cannot be measured, but it can be counted. Examples: number of students in the class, number of languages an individual speaks, show sizes.
# - Continuous data - the data that consists of numerical values that cannot be counted, but can be measured. Examples: height, weight. This type of data can be divided into intervals (represent ordered units that have the same difference, but do not have an absolute zero, for example: temperature) and ratio data (the same as interval values, with the difference that they do have an absolute zero, for example: height and weight).
#
# Categorical data:
#
# - Nominal data - the data that represents distinct categories with no order. Example: marital status (married, singled, divirced, widowed and so on), languages an individual speaks (English, Finnish, Swedish).
# - Ordinal data - the data that represents ordered categories. Example: education (Elementary, High School, Undergraduate, Graduate), customer satisfaction (satisfied, rather satisfied, rather unsatisfied, unsatisfied). The main limitation of this data type is that the distances (differences) between the values are not know.
#
# <i>Another good source to read about the data types is <a href="http://www.intellspot.com/data-types/">here</a></i>
#
# [More on data types.]("https://towardsdatascience.com/data-types-in-statistics-347e152e8bee")

# %% [markdown]
# ### Identifying the data type
# Take a look at the list of variables below and try to identify their data types.

# %% [markdown]
# <ol>
#     <li>Dogs' breeds</li>
#     <li>Lengths of the athletes' jumps</li>
#     <li>Songs' positions in the charts</li>
#     <li>Number of the times a student missed a class</li>
#     <li>Nationalities</li>
# </ol>
#
# <p>Answer options:</p>
# <ol>
#     <li>Numberical discrete data</li>
#     <li>Numberical continuous data</li>
#     <li>Categorical nominal data</li>
#     <li>Categorical ordinal data</li>
# </ol>

# %% [markdown]
# ### Answers
# - Dogs' breeds: 3
# - Lengths of the athletes' jumps: 2
# - Songs' positions in the charts: 4
# - Number of the times a student missed a class: 1
# - Nationalities: 3

# %% [markdown]
# ## Chapter 3.3: Data handling and processing <a class="anchor" id="chapter_3_3"></a>
#
# In this chapter, we will learn to process and manipulate our data with the handy package `pandas`.
#
# > Furthermore, there are various different data manipulation procedures other than those introduced in this chapter. Check the complete [turorial](https://codesource.io/data-preprocessing-for-machine-learning/) if you are interested.
#
# First, let's look at our data's description.

# %%
from sklearn.datasets import load_diabetes

data = pd.read_csv(os.path.join(DATA, 'diabetes_data.csv'))

# %% [markdown]
# <table>
#   <tr>
#     <th>Column</th>
#     <th>Type</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>Pregnancies</td>
#     <td>Numerical</td>
#     <td>Number of times pregnant</td>
#   </tr>
#   <tr>
#     <td>Glucose</td>
#     <td>Numerical</td>
#     <td>Plasma glucose concentration a 2 hours in an oral glucose tolerance test</td>
#   </tr>
#   <tr>
#     <td>BloodPressure</td>
#     <td>Numerical</td>
#     <td>Diastolic blood pressure (mm Hg)</td>
#   </tr>
#     <tr>
#     <td>SkinThickness</td>
#     <td>Numerical</td>
#     <td>Triceps skin fold thickness (mm)</td>
#   </tr>
#     <tr>
#     <td>Insulin</td>
#     <td>Numerical</td>
#     <td>2-Hour serum insulin (mu U/ml)</td>
#   </tr>
#   <tr>
#     <td>BMI</td>
#     <td>Numerical</td>
#     <td>Body mass index (weight in kg/(height in m)^2)</td>
#   </tr>
#   <tr>
#     <td>DiabetesPedigreeFunction</td>
#     <td>Numerical</td>
#     <td>A function that determines the risk of type 2 diabetes based on family history. The larger the function, the higher the risk of type 2 diabetes</td>
#   </tr>
#   <tr>
#     <td>Age</td>
#     <td>Numerical</td>
#     <td>Age (years)</td>
#   </tr>
#   <tr>
#     <td>Outcome</td>
#     <td>Boolean</td>
#     <td>Class 1 indicates person having diabetes and 0 indicates other</td>
#   </tr>
# </table>

# %% [markdown]
# In any case, it is always worthwhile to look at the data's statistics before doing any actual plotting. Now, let's look at our data's description by calling `pandas` built-in function `describe()`.

# %%
data.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1536.000000  1536.000000    1536.000000    1536.000000  1536.000000
# mean      3.845052   120.894531      69.105469      20.536458    79.799479
# std       3.368480    31.962202      19.349501      15.947021   115.206457
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      62.000000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    30.500000
# 75%       6.000000   140.250000      80.000000      32.000000   127.250000
# max      17.000000   199.000000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  1536.000000               1536.000000  1536.000000  1536.000000
# mean     31.992578                  0.471876    33.240885     0.348958
# std       7.881592                  0.331221    11.756400     0.476796
# ...

# %% [markdown]
# Notice that there are zero values in some features such as `BMI`, `BloodPressure`, which makes no sense in a medical setting. Looking at data's description helps us detect possible outliers earlier.

# %% [markdown]
# ### Detecting and handling duplicate values
#
# A real dataset often consists of multiple duplicate values, due to various reasons (technical errors, entry errors). We should always check for duplications from our data and get rid of them.
#
# First, we can check for duplications using the `duplicated` function.

# %%
duplicates = data[data.duplicated()]
print("Number of duplications:", len(duplicates))
# Out:
# Number of duplications: 768

# %%
 #let's visualize the duplicates
data[data.duplicated()]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 768             6      148             72             35        0  33.6
# 769             1       85             66             29        0  26.6
# 770             8      183             64              0        0  23.3
# 771             1       89             66             23       94  28.1
# 772             0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 1531           10      101             76             48      180  32.9
# 1532            2      122             70             27        0  36.8
# 1533            5      121             72             23      112  26.2
# 1534            1      126             60              0        0  30.1
# 1535            1       93             70             31        0  30.4
#
#       DiabetesPedigreeFunction  Age  Outcome
# 768                      0.627   50        1
# ...

# %% [markdown]
# There are quite a lot of duplications. We can get rid of them by calling the `drop_duplicates` function from `pandas`.

# %%
# drop the duplicate values
data = data.drop_duplicates()

# check for the changes
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# ### Detecting and handling missing values
#
# Missing values is one of the most common problems for digital health data. The mechanism for missing data can vary. They could arise from technical issues with the sensors, or from participants opting out of the study. In general, there are three different Missingness Mechanism:
#
# 1. **Missing Completely at Random (MCAR)**: The probability that a value is missing does not depend on
# either the observed or missing values of the response. For example: a participant in the study suddenly moves to a new area and no longer take part in the study. Often times, we *want* the missing data to be MCAR.
#
# 2. **Missing at Random (MAR)**: When missingness depends only on observed values and not on values that are missing. Example: a participant does not answer some of the survey's questions because the question is not written in their first language.
#
# 3. **Missing Not at Random (MNAR)**: This happens when neither MCAR or MAR holds. The probability of missingness depends on reasons that are not known. Example: Wealthy people often withdraw their income when surveyed. We can only make educated guess on that phenomenom but cannot confirm it, therefore the nature ofmissingness in income data is unknown. This is the worst case scenario, because we cannot make an assumption about the missing values.
#
# Let's see how many missing values there are in our data.

# %%
# Check for the missing values
data.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %% [markdown]
# It appears that our data is complete. However, as we have seen from the visualizations in the previous chapter, some of the entries consist of suspicious values, for example: zeroes in BloodPressure, Insulin, BMI. This is probably due to the encoding process on the original data, where missing values were imputed with zeroes. We can reverse this process and observe the changes.

# %%
# Assign NaN to the zero values in BP, Insulin and BMI
cols = ["BloodPressure","Insulin","BMI"]
data[cols] = data[cols].replace({'0':np.nan, 0:np.nan})

# Check the number of missing values in each column
data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                35
# SkinThickness                 0
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# Now, it seems like there are way more missing values than we thought. One of the most common strategy in this situation is simply dropping all the records with NaNs.

# %%
# drop records which contain missing values
data_dropped = data.dropna()
print("Number of rows after dropping missing records: ", len(data_dropped))
# Assert if there is any Nan in the filtered dataset
assert data_dropped.isnull().any().all() == False
# Out:
# Number of rows after dropping missing records:  393

# %% [markdown]
# Even though we have got rid of all the missing values, the resulting dataset shrinks significantly in size because we have removed 374 records with no `Insulin` information. In this scenario, it is better if we just simply drop the `Insulin` column.

# %%
data = data.drop(columns='Insulin')

# %% [markdown]
# **Note:** A common rule of thumb is that you can remove the missing rows if they account for less than 5% the size of your dataset.

# %% [markdown]
# ### Handling missing values for numerical values
#
# Although dropping missing values is the most convenient method, it is usually not the most optimal. As we have seen from the above example, the resulting dataset could be extremely small and will result in biased statistical measurements. To this end, we can utilize the Imputer to preserve the sample size. [SimpleImputer](https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html) can predict and fill in missing values with some statistics (e.g. mean, median, ...) retrieved from existing data.

# %%
from sklearn.impute import SimpleImputer # load simple imputer

# SimpleImputer is used to predicting missing values by their context (neighbors)

# Define the imputer. We use 'mean' as the imputing strategy.
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# predict column age
data['BloodPressure'] = imp_mean.fit_transform(data[['BloodPressure']])
# predict column salary
data['BMI'] = imp_mean.fit_transform(data[['BMI']])
# see the result after imputation
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0            6      148           72.0             35  33.6
# 1            1       85           66.0             29  26.6
# 2            8      183           64.0              0  23.3
# 3            1       89           66.0             23  28.1
# 4            0      137           40.0             35  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Check the number of missing data
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### Feature Scaling (Normalization)

# %% [markdown]
# Sometimes our data might consists of multiple features (also known as *dimensions*), where each feature has their own variance. Feature scaling is [important](https://scikit-learn.org/stable/auto_examples/preprocessing/plot_scaling_importance.html) in many situations. For example, certain algorithms such as clustering methods require the data to be normalized before feeding into the model.
#
# Among all functions, [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) is the most commonly used one.

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data_scaled = data.copy()
data_scaled.iloc[:,:-2] = sc.fit_transform(data_scaled.iloc[:,:-2]) # Exclude the last 2 columns
data_scaled
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness       BMI  \
# 0       0.639947  0.848324      -0.033518       0.907270  0.166292
# 1      -0.844885 -1.123396      -0.529859       0.530902 -0.852531
# 2       1.233880  1.943724      -0.695306      -1.288212 -1.332833
# 3      -0.844885 -0.998208      -0.529859       0.154533 -0.634212
# 4      -1.141852  0.504055      -2.680669       0.907270  1.548980
# ..           ...       ...            ...            ...       ...
# 763     1.827813 -0.622642       0.297376       1.722735  0.064409
# 764    -0.547919  0.034598      -0.198965       0.405445  0.632039
# 765     0.342981  0.003301      -0.033518       0.154533 -0.910750
# 766    -0.844885  0.159787      -1.026200      -1.288212 -0.343120
# 767    -0.844885 -0.873019      -0.198965       0.656358 -0.299456
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                    0.468492   50        1
# 1                   -0.365061   31        0
# ...

# %% [markdown]
# Wondering how the data looks like after scaling? Let's make a plot for each variable.

# %%
data_scaled.iloc[:,:-2].hist(figsize=(12, 12))
plt.show()

# %% [markdown]
# The scaled features are now in the same range with mean = 0.

# %% [markdown]
# ### Exercise: Preprocessing data
# Now, you should write your own data processing scripts based on what you have learned from the chapter so far.
#
# The `hepatitis_data.csv` dataset describes basic information of patients and it requires some pre-processing.

# %%
# loading the dataset

df = pd.read_csv(os.path.join(DATA, 'hepatitis.csv'))
# inspect
df.head()
# Out:
#    age     sex  bilirubin  alk_phosphate  albumin  protime class
# 0   30    male        1.0           85.0      4.0      NaN  live
# 1   50  female        0.9          135.0      3.5      NaN  live
# 2   78  female        0.7           96.0      4.0      NaN  live
# 3   31  female        0.7           46.0      4.0     80.0  live
# 4   34  female        1.0            NaN      4.0      NaN  live

# %%
df.describe()
# Out:
#               age   bilirubin  alk_phosphate     albumin     protime
# count  155.000000  149.000000     126.000000  139.000000   88.000000
# mean    41.200000    1.427517     105.325397    3.817266   61.852273
# std     12.565878    1.212149      51.508109    0.651523   22.875244
# min      7.000000    0.300000      26.000000    2.100000    0.000000
# 25%     32.000000    0.700000      74.250000    3.400000   46.000000
# 50%     39.000000    1.000000      85.000000    4.000000   61.000000
# 75%     50.000000    1.500000     132.250000    4.200000   76.250000
# max     78.000000    8.000000     295.000000    6.400000  100.000000

# %%
#MY PERSONAL ANALYSIS
# Create histograms for all numerical columns
numerical_columns = df.select_dtypes(include='number')

# Create subplots with two rows and a maximum of three columns in each row
num_cols = len(numerical_columns.columns)
num_rows = (num_cols - 1) // 3 + 1  # Calculate the number of rows

fig, axes = plt.subplots(num_rows, 3, figsize=(15, 5 * num_rows))

for i, col in enumerate(numerical_columns.columns):
    row_idx = i // 3  # Determine the row index
    col_idx = i % 3  # Determine the column index
    axes[row_idx, col_idx].hist(df[col], bins=20, color='royalblue', edgecolor="black")
    axes[row_idx, col_idx].set_title(f'Histogram of {col}')
    axes[row_idx, col_idx].set_xlabel(col)
    axes[row_idx, col_idx].set_ylabel('Frequency')
    axes[row_idx, col_idx].grid(True)

# Hide empty subplots if there are any
for i in range(num_cols, num_rows * 3):
    axes[i // 3, i % 3].axis('off')

plt.tight_layout()
plt.show()

# %%
# Exploring basic details

def basic_details(df):
    b = pd.DataFrame()
    b['Missing values'] = df.isnull().sum()
    b['N unique values'] = df.nunique()
    b['dtype'] = df.dtypes
    return b

print(basic_details(df))
# Out:
#                Missing values  N unique values    dtype
# age                         0               49    int64
# sex                         0                2   object
# bilirubin                   6               34  float64
# alk_phosphate              29               83  float64
# albumin                    16               29  float64
# protime                    67               44  float64
# class                       0                2   object

# %% [markdown]
# Here, in the "Missing values" column, you can see that `alk_phosphate`, `albumin` and `protime` columns consist of plenty of missing values. Try to improve the quality of the data using the methods you have learned above.

# %% [markdown]
# #### Task: Handle missing values using `dropna()`
# You should remove all the missing values from the dataset.

# %%
df_dropped = df.copy() #Treat df_dropped as original df and perform all the manipulations on df_dropped
df_dropped.dropna(inplace=True)

# %%
basic_details(df_dropped)
# Out:
#                Missing values  N unique values    dtype
# age                         0               41    int64
# sex                         0                2   object
# bilirubin                   0               24  float64
# alk_phosphate               0               61  float64
# albumin                     0               25  float64
# protime                     0               44  float64
# class                       0                2   object

# %% [markdown]
# Upon removing the missing values from the dataset, it is evident that the number of unique values for certain features has undergone a change. The removal of rows containing missing values has resulted in the reduction of unique values in some columns compared to the original dataset, where those missing values were contributing to the uniqueness of values in those columns.

# %%
# Hidden tests

# %% [markdown]
# #### Task: Handle missing values using `SimpleImputer`
# Instead of removing the missing values, impute the following columns with their mean values: `alk_phosphate`, `albumin`, `protime`, `bilirubin`.

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

df_imputed = df.copy() #Treat df_imputed as original df and perform all the manipulations on df_imputed

# %%
# Impute the following columns with their mean values: alk_phosphate, albumin, protime, bilirubin

# Columns to impute
columns_to_impute = ["alk_phosphate", "albumin", "protime", "bilirubin"]

# Fit and transform the imputer on the selected columns
df_imputed[columns_to_impute] = imp_mean.fit_transform(df_imputed[columns_to_impute])

# %%
basic_details(df_imputed)
# Out:
#                Missing values  N unique values    dtype
# age                         0               49    int64
# sex                         0                2   object
# bilirubin                   0               35  float64
# alk_phosphate               0               84  float64
# albumin                     0               30  float64
# protime                     0               45  float64
# class                       0                2   object

# %% [markdown]
# In this case, we can observe that by using the SimpleImputer, the number of missing values becomes zero. Additionally, the number of unique values has slightly changed since we introduced new numerical values.

# %%
# Hidden tests

# %% [markdown]
# #### Task: Scale data using `StandardScaler`
#
# Scale the following columns with Standard scaler: `alk_phosphate`, `albumin`, `protime`, `bilirubin`.

# %%
# define the scaler
sc = StandardScaler()

df_scale = df.copy() #Treat df_scale as original df and perform scaling on df_scale

# %%
# YOUR CODE HERE
columns_to_scale = ["alk_phosphate", "albumin", "protime", "bilirubin"]
df_scale[columns_to_scale] = sc.fit_transform(df_scale[columns_to_scale])

# %%
#MY PERSONAL ANALYSIS
# Create histograms for all numerical columns
numerical_columns = df_scale.select_dtypes(include='number')

# Create subplots with two rows and a maximum of three columns in each row
num_cols = len(numerical_columns.columns)
num_rows = (num_cols - 1) // 3 + 1  # Calculate the number of rows

fig, axes = plt.subplots(num_rows, 3, figsize=(15, 5 * num_rows))

for i, col in enumerate(numerical_columns.columns):
    row_idx = i // 3  # Determine the row index
    col_idx = i % 3  # Determine the column index
    axes[row_idx, col_idx].hist(df_scale[col], bins=20, color='royalblue', edgecolor="black")
    axes[row_idx, col_idx].set_title(f'Histogram of {col}')
    axes[row_idx, col_idx].set_xlabel(col)
    axes[row_idx, col_idx].set_ylabel('Frequency')
    axes[row_idx, col_idx].grid(True)

# Hide empty subplots if there are any
for i in range(num_cols, num_rows * 3):
    axes[i // 3, i % 3].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Let's check if df_scale has been properly scaled: for this reason we compute the mean and standard deviation of the scaled columns.

# %%
mean_values = df_scale[columns_to_scale].mean()
std_deviation_values= df_scale[columns_to_scale].std()

# %%
mean_values
# Out:
# alk_phosphate    8.458842e-17
# albumin         -1.392970e-15
# protime          0.000000e+00
# bilirubin       -4.768743e-17
# dtype: float64

# %%
std_deviation_values
# Out:
# alk_phosphate    1.003992
# albumin          1.003617
# protime          1.005731
# bilirubin        1.003373
# dtype: float64

# %% [markdown]
# We can notice that mean is close to 0 and the standard deviation is close to 1 for the scaled columns.

# %%
# Hidden tests

# %% [markdown]
# ## Chapter 3.4: Plottings Techniques (Visualization) <a class="anchor" id="chapter_3_4"></a>
# In this chapter, you can view snippets and practice various plotting functions with seaborn and matplotlib.

# %% [markdown]
# ### 3.4.1 Univariate plot
#
# Univariate plot is used to visualize the distribution of one variable. Probably the most commonly used univariate plot is histogram.

# %%
# Initialize a figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,6))

title = fig.suptitle("Histogram of Blood Pressure")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# Make a scatter plot with matplotlib
ax1.hist(data['BloodPressure'])
ax1.set_xlabel("value")
ax1.set_ylabel("frequency")
ax1.set_title("matplotlib")

# Make a scatter plot with seaborn
sns.histplot(data['BloodPressure'], ax=ax2)
ax2.set(xlabel='value', ylabel='frequency', title="seaborn")
plt.show()

# %% [markdown]
# You can easily see that there are quite a few outliers values in the data (Blood pressure = 0). Consequently, we will need to get rid of these data in the preprocessing step.

# %% [markdown]
# ### 3.4.2 Multivariate plot
#
# [explain multivariate plots]:
# - Shows the relationship between several variables
# - Most of the times, we are interested in plots that show the relationship between two variables. We call them bivariate plots.
#
# [showcase the following plots: lineplot, correlation heatmap, scatter plot]

# %% [markdown]
# #### Scatter plot
# First, let's look at scatter plot. We often use this kind of plot to reveal the relationship between 2 variables.

# %%
# Initialize a figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,6))

title = fig.suptitle("Blood pressure versus Age")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# Make a scatter plot with matplotlib
ax1.scatter(data['BloodPressure'], data['Age'])
ax1.set_xlabel("BloodPressure")
ax1.set_ylabel("Age")
ax1.set_title("matplotlib")

# Make a scatter plot with seabor
sns.scatterplot(x=data['BloodPressure'], y=data['Age'], ax=ax2)
ax2.set_title("seaborn")
plt.show()

# %% [markdown]
# You can also combine the histogram and scatter plots into one, by calling `seaborn`'s `pairplot` function.

# %%
pairplot = sns.pairplot(data)
plt.show()
pairplot.savefig('pairplot.png')
# Out:
# /opt/software/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# &#x1F4DD; **Task:** Do you notice any patterns or abnormality from the above plot?

# %% [markdown]
# I can observe that there is a positive correlation between skin thickness and BMI, meaning that people with higher BMIs tend to have thicker skin. Searchin on internet I have read that this is because the subcutaneous tissue, which makes up the majority of skin thickness, is made up of fat cells. As BMI increases, so does the amount of fat in the subcutaneous tissue, and therefore the overall thickness of the skin.
#
# It appears that there is a sligthly positive correlation between pregnancies and age, indicating that as age increases (within physiological limits, of course), it is more likely to observe pregnant candidates. Regarding the pregnancies category, the histogram also shows a right-skewed distribution, indicating that most patients have had few pregnancies.
#
# Another positive correlation exists between blood pressure and age, indicating that blood pressure increases with age.
#
# An abnormality concerns the presence of samples in which skin thickness is zero, which is obviously not physiologically possible.

# %% [markdown]
# #### Boxplot/Violin plot
# When there are grouping factors within our data (for instance: gender, origin), boxplot often helps reveal the trend within each group.
#
# Now, since there is no grouping factor in our current data, we will come up with an arbitrary one. Let's sort people into different age groups.

# %%
# Young: age < 32
# Middle age: age >= 32 and age < 50
# Old: age >= 50
data['AgeGroup'] = data['Age'].apply(lambda x: 'Young' if x < 32 else ('Middle age' if (x >= 32 and x < 50) else 'Old'))

# %% [markdown]
# Alright, let's make a boxplot. This time we will use `pandas` built-in function `boxplot` for a change. In fact, `pandas` provides many useful built-in plotting functions that you can explore from [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html).

# %%
# Initialize a figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,8))
fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# Make a scatter plot with pandas
data.boxplot(column=['BloodPressure'], by=['AgeGroup'], ax=ax1)
ax1.set_ylabel("BloodPressure")
ax1.set_xlabel("Age group")
ax1.set_title("pandas")

# Make a boxplot with seaborn
sns.boxplot(x=data['AgeGroup'], y=data['BloodPressure'], ax=ax2)
ax2.set_xlabel("Age group")
ax2.set_title("seaborn")
plt.show()

# %% [markdown]
# &#x1F4DD; **Task:** Do you notice any pattern from the above plot?

# %% [markdown]
# * Young Age Group: The blood pressure values for this group are the lowest, ranging approximately from 60 to 100.
# * Middle Age Group: The blood pressure values for this group are slightly higher than the young age group, ranging approximately from 70 to 110.
# * Old Age Group: This group has the highest blood pressure values, ranging approximately from 80 to 120.
#
# From this plot, it appears that blood pressure tends to increase with age.

# %% [markdown]
# **Violin plot** is another way to visualize group difference. Violin plot is more informative than a plain boxplot, since it also shows the full distribution of the data.

# %%
# Make a violin with seaborn
fig, ax = plt.subplots(1, 1, figsize = (12,6))
sns.violinplot(x=data['AgeGroup'], y=data['BloodPressure'], ax=ax)
ax.set_xlabel("Age group")
plt.show()

# %% [markdown]
# #### Correlation heatmap
#
# Correlation is a statistical measure to describe the extent in which two variables are linearly related. Correlation can range from -1 to 1.  We use correlation heatmap to show the strength of correlation between different variables.

# %%
numerical_cols = data.columns[:-2]
fig, ax = plt.subplots(figsize=(14,14))         # Sample figsize in inches
sns.heatmap(data[numerical_cols].corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ### 3.4.3. Practice: Make some plots by yourself
#
# Now, it's time for you to make some plots for a real dataset. You should use the `seaborn` package for this assignment.

# %%
from datetime import datetime

# %%
# load sample dataset
df = pd.read_csv(os.path.join(DATA, '1503960366_dailyCaloriesAndSteps.csv'), sep=";")
df.head()
# Out:
#            Id ActivityDay  Calories  TotalSteps
# 0  1503960366   4.12.2016      1985       13162
# 1  1503960366   4/13/2016      1797       10735
# 2  1503960366   4/14/2016      1776       10460
# 3  1503960366   4/15/2016      1745        9762
# 4  1503960366   4/16/2016      1863       12669

# %% [markdown]
# #### Task: Make a plot for `ActivityDay` and `Calories`
#
# Hint: For timeseries data, [line plot](https://seaborn.pydata.org/generated/seaborn.lineplot.html) is the most informative visualization.

# %%
# Calories line plot

plt.figure(figsize=(16,4))
sns.lineplot(data=df, x='ActivityDay', y='Calories')
#I also added a scatterplot for a better visualization
sns.scatterplot(data=df, x='ActivityDay', y='Calories', color='red', marker='o')
plt.title("Daily Calories Burned", pad=20, fontsize=24)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Task: Similarly, make a plot for `ActivityDay` and `TotalSteps`

# %%
# TotalSteps line plot

plt.figure(figsize=(16, 4))
sns.lineplot(data=df, x='ActivityDay', y='TotalSteps')
sns.scatterplot(data=df, x='ActivityDay', y='TotalSteps', color='red', marker='o')
plt.title("Daily Total Steps", pad=20, fontsize=24)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# &#x1F4DD; **Task:** Do you observe any noticeable trend from the above plot? If yes, write your observation in this cell.

# %% [markdown]
# My observations are presented after the following plot.

# %%
plt.figure(figsize=(16, 8))

# Create the first line plot for 'ActivityDay' and 'Calories'
plt.subplot(2, 1, 1)
sns.lineplot(data=df, x='ActivityDay', y='Calories')
sns.scatterplot(data=df, x='ActivityDay', y='Calories', color='red', marker='o')
plt.title("Daily Calories Burned", fontsize=16)
plt.xticks(rotation=45)

# Create the second line plot for 'ActivityDay' and 'TotalSteps'
plt.subplot(2, 1, 2)
sns.lineplot(data=df, x='ActivityDay', y='TotalSteps')
sns.scatterplot(data=df, x='ActivityDay', y='TotalSteps', color='red', marker='o')
plt.title("Daily Total Steps", fontsize=16)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Comparing the two graphs, it is possible to notice a strong correlation between the number of calories burned in a day and the number of steps taken on the same day. This means that the more steps taken, the more calories are burned.

# %%
#Here I'm adding a column that convert the 
# ActivityDay in the corresponding WeekDay
conv_df = df.copy()
conv_df['ActivityDay'] = conv_df['ActivityDay'].str.replace('/', '.')
conv_df['ActivityDay'] = pd.to_datetime(conv_df['ActivityDay'])
conv_df['WeekDay'] = conv_df['ActivityDay'].dt.day_name()
conv_df.head()
# Out:
#            Id ActivityDay  Calories  TotalSteps    WeekDay
# 0  1503960366  2016-04-12      1985       13162    Tuesday
# 1  1503960366  2016-04-13      1797       10735  Wednesday
# 2  1503960366  2016-04-14      1776       10460   Thursday
# 3  1503960366  2016-04-15      1745        9762     Friday
# 4  1503960366  2016-04-16      1863       12669   Saturday

# %%
# Make boxplots of calories and steps per week day
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Create subplots for 'Calories' and 'TotalSteps'
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))


sns.boxplot(x='WeekDay', y='Calories', data=conv_df, order=order, ax=ax1)
ax1.set_title('Calories by Day of the Week')
ax1.set_xlabel('Day of the Week')
ax1.set_ylabel('Calories')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
ax1.grid()


sns.boxplot(x='WeekDay', y='TotalSteps', data=conv_df, order=order, ax=ax2)
ax2.set_title('Total Steps by Day of the Week')
ax2.set_xlabel('Day of the Week')
ax2.set_ylabel('Total Steps')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
ax2.grid()

plt.subplots_adjust(hspace=1)

# Show the combined plot
plt.show()

# %% [markdown]
# From this plot it is possible to notice that most of the steps, and consequently, calories burned, are taken on Monday, Tuesday, and Saturday, while Sunday is the day with the lowest physical activity.

# %% [markdown]
# #### Task: Make histograms of `Calories` and `TotalSteps`
# Comply with the following criteria:
# - set parameter `kde=True` to see the kernel density estimate
# - set parameter `height=6` and `aspect=2` to fix the size of the plot
#
# The [sns.displot](https://seaborn.pydata.org/generated/seaborn.displot.html) is a Figure-level interface for drawing distribution plots onto a FacetGrid. It provides you more control of the plot and does not fully comply with the meta-data definded by `matplotlib`
#
# For instance, if you want to adjust the size of the `FacetGrid`, you should define `height` and `aspect` in the `sns.displot` function, rather than using the `figsize=` definition in the `plt.figure()` function.

# %%
# Calories histogram

# Create a FacetGrid using sns.displot
g = sns.displot(df, x='Calories', kde=True, height=6, aspect=2)
g.fig.suptitle("Calories Histogram", fontsize=16)

plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/software/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# TotalSteps histogram

# Create a FacetGrid using sns.displot for 'TotalSteps'
g = sns.displot(df, x='TotalSteps', kde=True, height=6, aspect=2)
g.fig.suptitle("TotalSteps Histogram", fontsize=16)

plt.show()
# Out:
# /opt/software/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Task: Make a scatter plot of `Calories` AND `TotalSteps`

# %%
# Scatter plot

# Create a scatter plot of 'Calories' and 'TotalSteps'
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='TotalSteps', y='Calories', s=100, color="red", edgecolor="black")

#I also added a linear fit
sns.regplot(data=df, x='TotalSteps', y='Calories', color="blue", scatter=False)

plt.title("Calories vs TotalSteps Scatter Plot", fontsize=25)
plt.xticks(rotation=45)
plt.grid()
 
plt.show()

# %% [markdown]
# &#x1F4DD; **Task:** Do you observe any trend from the plot?

# %% [markdown]
# As previously inferred, there is a positive correlation between calories burned and the number of steps taken. It can also be observed that the relationship is of a linear nature.

# %% [markdown]
# ## Chapter 4: Basic concepts of Machine Learning <a class="anchor" id="chapter_4"></a>

# %% [markdown]
# This chapter introduces various techniques like clustering, linear regression and classfification with several hand-on coding sections.
#
# Don't panic if you don't have any experience with machine learning. In the future assignments, we will only cover a **tiny bit** of it with good explanations.
#
# Before going into the concepts, we first define a few techical terms that will be used repeatedly below.
#
# 1. **Depedent variable (DV)**: the effect that we want to measure. In some literatures, they can be referred to as the *outcome* or the *response variable*.
#
# 2. **Indepent variable(s) (IVs)**: the factors that we believe to have an effect on the depedent variable. They are often referred to as *explanatory variables* or *predictor variables*.
#
# 3. **Statisical model**: a mathematical method to draw inference between the set of variables. In other words, model is a simpler and convenient way to simulate a real-world phenomenom.
#
# We often define a model as follows:
#
# $$DV \sim \alpha + IV_1 + IV_2 + ... + IV_n$$
#
# where $\alpha$ is an indepedent term (we call this the *intercept*).

# %% [markdown]
# ### 4.1 Supervised learning

# %% [markdown]
# [Supervised learning](https://en.wikipedia.org/wiki/Supervised_learning) is a group of learning algorithms ( = models) that are trained using labeled data. The supervised learning algorithm learns from this labeled data through an iterative process which then allows it to perform predictions on new unseen data. Supervised learning is further divided into Regression and Classification algorithms.

# %% [markdown]
# #### 4.1.1 Linear Regression
#
# Regression analysis is a statistical methodology that estimate a relationship between a dependent variable and a set of independent variables. Linear regression is the most basic form of regression analysis and is used extensively in digital health data analysis [5,6]. In linear regression, the relationship between the variables are assumed to be linear. Typically, we can achieve two tasks by using linear regression:
#
# 1. Predicting the value of a variable based on the value of other variables.
#
# 2. Yielding the estimates between a dependent variable and a set of independent variables
#
# There are a few articles ([here](https://towardsdatascience.com/linear-regression-explained-1b36f97b7572) and [here](https://medium.com/analytics-vidhya/understanding-the-linear-regression-808c1f6941c0)) that explain the concept of linear regression in details.

# %% [markdown]
# **Splitting the dataset**

# %% [markdown]
# Typically, we would like to split the dataset into two subsets: one for training the model and one for testing. We can easily achieve this by using the [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function from the [scikit-learn](https://scikit-learn.org/stable/index.html).

# %%
# Splitting Dataset into Training and Test Set

from sklearn.model_selection import train_test_split

# Independent variables: we will use a few variables to predict the outcome
iv_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Age', 'DiabetesPedigreeFunction']
X = data_scaled[iv_cols]
y = data_scaled['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

print("Train sample size:", len(X_train))
print("Test sample size:", len(X_test))
# Out:
# Train sample size: 614
# Test sample size: 154

# %% [markdown]
# We will use the [LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) model from scikit-learn for a simple prediction task. Now, we formally define our model as follows:
#
# $$Outcome \sim Pregnancies + Glucose + BloodPressure + SkinThickness + Age + DiabetesPedigreeFunction$$

# %%
 # importing LinearRegression model from the sklearn library
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression().fit(X_train, y_train) # Training Linear Regression model

print("[1] R-squared score: ", lin_reg.score(X_train, y_train)) # Return the mean accuracy on the given test data and labels
print("[2] Calculated coefficients: ", lin_reg.coef_) # Calculated coefficients for the linear regression problem
print("[3] Independent term: ", lin_reg.intercept_) # Independent term in the linear model

print("[4] Predicting the first 10 datapoints from test set: ", lin_reg.predict(X_test.head(10)))
# Out:
# [1] R-squared score:  0.2847789098367821
# [2] Calculated coefficients:  [0.08769845 0.20884834 0.01186254 0.02631357 0.00039821 0.05534777]
# [3] Independent term:  0.34153654015369095
# [4] Predicting the first 10 datapoints from test set:  [ 0.0456657   0.30329275  0.12597636  0.20582111  0.46535057  0.08880786
#   0.04875896  0.61291993 -0.01083871  0.56526852]

# %% [markdown]
# Let's iterate through our results:
#
# [1] R-squared score shows how well our model captures the variance of the dependent variable (the higher the better, max value is 1). A value of 0.28 is relatively low, which means that our model does not explain the variance well enough.
#
# [2] Coefficients show the strength and direction of the relationship between the dependent variables and its independent variables. You can see that `Glucose` has the highest coefficient values among all (0.209).
#
# [3] Indepent term is the value of the intercept. Combining this with the coefficients above, we can yield the following estimate:
#
# $$Outcome = 0.355 + 0.088*Pregnancies + 0.201*Glucose + 0.012*BloodPressure  \\
# + 0.026*SkinThickness + 0.005*Age + 0.055*DiabetesPedigreeFunction$$
#
# [4] Finally, we can make a prediction on the test set. There are various ways to validate this prediction result, but we will not dwell into too much details in this assignment.

# %% [markdown]
# **What if we did not normalize the data?**
#
# Now you will see why standardization/normalization is important. We will fit the same model again, but with the original data.

# %%
X_orig = data[iv_cols]
y_orig = data['Outcome']
X_orig_train, X_orig_test, y_orig_train, y_orig_test = train_test_split(X_orig, y_orig, test_size=0.2, random_state=2)

lin_reg = LinearRegression().fit(X_orig_train, y_orig_train) # Training Linear Regression model

print("[1] R-squared score: ", lin_reg.score(X_orig_train, y_orig_train)) # Return the mean accuracy on the given test data and labels
print("[2] Calculated coefficients: ", lin_reg.coef_) # Calculated coefficients for the linear regression problem
print("[3] Independent term: ", lin_reg.intercept_) # Independent term in the linear model
# Out:
# [1] R-squared score:  0.284778909836782
# [2] Calculated coefficients:  [0.0260435  0.00653636 0.00098131 0.0016506  0.00039821 0.16715684]
# [3] Independent term:  -0.732638654809691

# %% [markdown]
# See how the estimates have changed? The effect of `Glucose` is *underestimated* while the effect of `DiabetesPedigreeFunction` is *overestimated* because they are not in the same value range. We say that the estimates are *biased* in this scenario.

# %% [markdown]
# #### 4.1.2 Logistic regression
#
# [Logistic Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) is another regression analysis method. Logistic model can predict the probability that an outcome belong to a class.
#
# It's highly recommended to read this [article](https://www.analyticsvidhya.com/blog/2021/04/beginners-guide-to-logistic-regression-using-python/) to learn more about regression.
#
# **You don't need to understand any mathematical parts, and having a general idea about what regression does is adequate.**

# %%
from sklearn.datasets import load_iris # Loading the data
from sklearn.linear_model import LogisticRegression # Importing LogisticRegression model from the sklearn library

# define the logistic regression model
log_reg = LogisticRegression(random_state=0) 

# Training Logistic Regression model
log_reg.fit(X_train, y_train)

# validate model accuracy with test samples
log_reg.score(X_test, y_test)

print("Probability estimates: \n ", log_reg.predict_proba(X_test[:10])) # Probability estimates
print("R-squared score: ", log_reg.score(X, y)) # Return the mean accuracy on the given test data and labels
print("Predicting the label for the unseen datapoint: ", log_reg.predict(X_test[:10]))
# Out:
# Probability estimates:
#   [[0.92461836 0.07538164]
#  [0.73641915 0.26358085]
#  [0.8888424  0.1111576 ]
#  [0.83854205 0.16145795]
#  [0.55260619 0.44739381]
#  [0.90725348 0.09274652]
#  [0.92412781 0.07587219]
#  [0.32404517 0.67595483]
#  [0.94413535 0.05586465]
#  [0.39988125 0.60011875]]
# R-squared score:  0.76171875
# Predicting the label for the unseen datapoint:  [0 0 0 0 0 0 0 1 0 1]

# %% [markdown]
# As you can see from above, Logistic regression yield the probability that a sample belongs to a group. Logistic regression is particularly useful when the depedent variable consists of more than 2 classes.

# %% [markdown]
# ### 4.2 Unsupervised learning

# %% [markdown]
# <p><b><a href="https://en.wikipedia.org/wiki/Unsupervised_learning">Unsupervised learning </a></b> - group of learning algorithms ( = models) that are fed with unlabeled data. It is up to the algorithm to find hidden structures, patterns, or relationships within the data.
#
# Clustering algorithms and Dimensionality reduction are commonly used methods for unsupervised machine learning tasks.</p>
# <h4>Examples:</h4>
# <h4><a href="https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html"> K-means clustering algorithm:</a></h4>
# <p><i>Read more anout clustering <a href="https://www.geeksforgeeks.org/clustering-in-machine-learning/">here</a> and <a href="https://www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-k-means-clustering/">here</a> and about K-means clustering <a href="https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1">here</a></i></p>

# %%
from sklearn.cluster import KMeans # Importing KMeans model from the sklearn library

df_0 = X[['BloodPressure', 'Age']].copy()
df_0['pred_label'] = KMeans(n_clusters=2, random_state=0).fit_predict(df_0) 

sns.scatterplot(x="Age", y="BloodPressure", hue="pred_label", data=df_0);
plt.legend(loc='lower right');
# Out:
# /opt/software/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# The K-means algorithm attemps to separate the datapoints into clusters. As you can observe from the above plot, there is a cut-off point between the two clusters, a sign that the `BloodPressure` level starts to change once you get older. Hard to conclude anything just from the plot alone, but you have a general idea of how clustering works. Feel free to tinker with the `n_clusters` variable if you need more clusters.

# %% [markdown]
# ### 4.3 Natural Language Processing (NLP) techniques
# We introduce some NLP techniques here, which will be further used in assignment 5. Don't worry, it's not that hard if you are willing to spend an hour reading the concepts, and we will **NOT** using extra techniques other than those covered here.
#
# We use the python `NLP` module. The NLTK module is a massive tool kit, aims at helping you with the entire NLP methodology.
# In order to install NLTK, run the following commands in your terminal.
#
# Some terms you need to understand:
# - Corpus: Body of text, singular. Corpora is its plural.
# - Lexicon: Words and their meanings.
# - Token: Each “entity” that is a part of whatever was split up based on rules. For examples, each word is a token when a sentence is "tokenized" into words. Each sentence can also be a token, if you tokenize the sentences out of a paragraph. So basically, tokenizing involves splitting sentences and words from the body of the text.
#
# Ref:
# https://www.geeksforgeeks.org/tokenize-text-using-nltk-python/
#
# Below, we present a simple and commonly used template.

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize # string tokenizer

import ssl

# Bypass ssl to enable downloading punkt package
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt', quiet=True)
text = "How do we improve health and well-being using digital data? Is it a kind of magic?"

# %%
# tokens for each complete sentence
sent_token = sent_tokenize(text)

sent_token
# Out:
# ['How do we improve health and well-being using digital data?',
#  'Is it a kind of magic?']

# %%
# tokens for each word repectively in a list
word_token = word_tokenize(text)

word_token
# Out:
# ['How',
#  'do',
#  'we',
#  'improve',
#  'health',
#  'and',
#  'well-being',
#  'using',
#  'digital',
#  'data',
#  '?',
#  'Is',
#  'it',
#  'a',
#  'kind',
#  'of',
#  'magic',
#  '?']

# %%
from nltk.stem import PorterStemmer # word stem extractor

ps = PorterStemmer()

# extract the stems of each word token
word_stem = [ps.stem(w) for w in word_tokenize(text)]

print(word_stem)
# Out:
# ['how', 'do', 'we', 'improv', 'health', 'and', 'well-b', 'use', 'digit', 'data', '?', 'is', 'it', 'a', 'kind', 'of', 'magic', '?']

# %%
# compare the word stem and the word token
np.column_stack([word_stem, word_token])
# Out:
# array([['how', 'How'],
#        ['do', 'do'],
#        ['we', 'we'],
#        ['improv', 'improve'],
#        ['health', 'health'],
#        ['and', 'and'],
#        ['well-b', 'well-being'],
#        ['use', 'using'],
#        ['digit', 'digital'],
#        ['data', 'data'],
#        ['?', '?'],
#        ['is', 'Is'],
#        ['it', 'it'],
#        ['a', 'a'],
#        ['kind', 'kind'],
#        ['of', 'of'],
#        ['magic', 'magic'],
#        ['?', '?']], dtype='<U10')

# %% [markdown]
# ### Extra reading: Statistical test
#
# Statistical tests are often conducted in behavioural studies to measure the difference in some variables between multiple groups. Before going into the details of statistical testing, we first need to understand the concepts of *null hypothesis* and *alternate hypothesis*.
#
# A *null hypothesis* ($H_0$) proposes that there is no significant difference exists in a set of observations. The *alternate hypothesis* ($H_a$), on the other hand, is the direct opposite of the *null hypothesis*.
#
# **Why does this matter?**
#
# In almost every research problems, we often come up with multiple hypotheses and work to disprove/approve them. For example, to test the effect of a new drug, the gold standard in clinical practice is randomized control trials (RCT). In RCT, the participants are divided into two groups: treatment and control. In the end of the experiment, the researchers compare an outcome between the two groups, e.g: the cholesterol level. The hypotheses in this case are then defined as:
#
# $H_0$: there is no significant difference in the cholesterol level between two groups
#
# $H_a$: there is a significant difference in the cholesterol level
#
# Of course we would want to *reject* the null hypothesis and confidently say that there is a significant difference between the two treatments. This is where the statistical tests come into play. A statisical test describes how much the relationship between variables differ from the null hypothesis of no relationship. The test yields a test statistic from which we can use to compare against a critical value and decide to reject/accept the null hypothesis.
#
# The choice of a suitable statistical test is often a confusing topic. Statistical test are divided into two categories: parametric and non-parametric. In parametric tests, certain assumptions must hold, e.g: Independence of observations, Homogeneity of variance, and Normality of data. On the other hand, nonparametric tests do not require the above assumptions, but they often yield 'weaker' inference power than parametric tests.
#
# Here, we will briefly explain two statistical tests: t-test (parametric) and  permutation test (non-parametric). You can follow this [link](https://www.scribbr.com/statistics/statistical-tests/) for more in-depth explanation regarding statistical testing in general.

# %% [markdown]
# **Independent t-test**
#
# We use independent t-test to compare the means of a continuous outcome between two separate groups of individuals (male-female, treament-control).

# %%
from scipy import stats
stats.ttest_ind(data_scaled[data_scaled.Outcome==0]['Glucose'],data_scaled[data_scaled.Outcome==1]['Glucose'])
# Out:
# Ttest_indResult(statistic=-14.600060005973901, pvalue=8.935431645289273e-43)

# %% [markdown]
# Above, we just compare the difference in Glucose level between group of people who have diabete and those who don't. You can see that the pvalue is extremely low, which means that we can reject the null hypthesis.

# %% [markdown]
# **Permutation test**
#
#
# Permutation test follow a three steps procedure:
#
# 1. Compute a test statistic for the original data
#
# 2. Resample the data *n* times and yield *n* test statistics, to create a sampling distribution of the test statistics.
#
# 3. Ccompute the p-value as the percentage of test statistics that are as extreme or more extreme than the one originally observed.
#
# Permutation test is useful when the data generation mechanism is unknown, i.e we assume that we do not know about the underlying distribution. A really nice visual explanation: https://www.jwilber.me/permutationtest/

# %% [markdown]
# # References <a class="anchor" id="references"></a>
#
# [1] Digital health. (2022). Retrieved 25 April 2022, from https://www.euro.who.int/en/health-topics/Health-systems/digital-health
#
# [2] Moshe, I., Terhorst, Y., Opoku Asare, K., Sander, L., Ferreira, D., & Baumeister, H. et al. (2021). Predicting Symptoms of Depression and Anxiety Using Smartphone and Wearable Data. Frontiers In Psychiatry, 12. doi: 10.3389/fpsyt.2021.625247
#
# [3] Faurholt-Jepsen, M., Vinberg, M., Frost, M., Christensen, E., Bardram, J., & Kessing, L. (2015). Smartphone data as an electronic biomarker of illness activity in bipolar disorder. Bipolar Disorders, 17(7), 715-728. doi: 10.1111/bdi.12332
#
# [4] De Choudhury, M., Kiciman, E., Dredze, M., Coppersmith, G., & Kumar, M. (2016). Discovering Shifts to Suicidal Ideation from Mental Health Content in Social Media. Proceedings Of The 2016 CHI Conference On Human Factors In Computing Systems. doi: 10.1145/2858036.2858207
#
# [5] Do, D., Garfein, R., Cuevas-Mota, J., Collins, K., & Liu, L. (2019). Change in Patient Comfort Using Mobile Phones Following the Use of an App to Monitor Tuberculosis Treatment Adherence: Longitudinal Study. JMIR Mhealth And Uhealth, 7(2), e11638. doi: 10.2196/11638
#
# [6] Unnikrishnan, V., Shah, Y., Schleicher, M., Strandzheva, M., Dimitrov, P., & Velikova, D. et al. (2020). Predicting the Health Condition of mHealth App Users with Large Differences in the Number of Recorded Observations - Where to Learn from?. Discovery Science, 659-673. doi: 10.1007/978-3-030-61527-7_43
